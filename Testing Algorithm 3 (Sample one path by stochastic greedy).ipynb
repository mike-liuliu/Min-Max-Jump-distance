# %%
exec(open("./funcs/algo_2_and_3_funcs.py").read())

# %%
np.random.seed(123)
random.seed(123)

# %%
test_data_145 = pickle.load(  open( "./data/test_data_145.p", "rb" ) )

# %%
X = test_data_145[3]

    
temmpp = random.sample(range(len(X)), k=100)

X = X[temmpp]
 
plt.scatter(X[:,0],X[:,1])

# %%
distance_matrix = pairwise_distances(X)

# %%
start_id = 93
end_id = 25

# %%
k = 3
show_path = True

max_jump = Algorithm_3_Sample_one_path_by_stochastic_greedy(X, start_id, end_id , distance_matrix, k, show_path)

# %%
print(f"The maximum jump in the sampled path is {max_jump}.")
# Out:
# The maximum jump in the sampled path is 0.6831917031820579.
